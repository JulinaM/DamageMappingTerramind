# %%
# !python3 ../../scripts/rank_multirun_results.py  /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/
# Out:
# run_name  best_epoch  best_val_loss  best_IoU  best_Accuracy  best_Precision  best_Recall  best_F1  overrides                                                                                                                                                                                   run_dir
# --------  ----------  -------------  --------  -------------  --------------  -----------  -------  ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  --------------------------------------------------------------------------------------------------------------------------------------------------
# 17        5           0.2555         0.6709    0.946          0.7035          0.9352       0.803    trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=4; train_loader.num_augmentations=5; train_loader.batch_size=20  /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/17
# 14        5           0.325          0.6631    0.9466         0.7217          0.8909       0.7974   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=4; train_loader.num_augmentations=4; train_loader.batch_size=20  /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/14
# 7         5           0.1739         0.6354    0.9358         0.6543          0.9567       0.7771   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=3; train_loader.num_augmentations=5; train_loader.batch_size=8   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/7
# 4         5           0.208          0.6276    0.9358         0.6614          0.9247       0.7712   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=3; train_loader.num_augmentations=4; train_loader.batch_size=8   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/4
# 15        5           0.1807         0.6248    0.9328         0.6434          0.9559       0.7691   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=4; train_loader.num_augmentations=5; train_loader.batch_size=4   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/15
# 12        5           0.1963         0.6194    0.932          0.642           0.9463       0.765    trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=4; train_loader.num_augmentations=4; train_loader.batch_size=4   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/12
# 3         5           0.2014         0.6171    0.9327         0.6486          0.9269       0.7632   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=3; train_loader.num_augmentations=4; train_loader.batch_size=4   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/3
# 6         5           0.1678         0.6124    0.9285         0.6259          0.9659       0.7596   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=3; train_loader.num_augmentations=5; train_loader.batch_size=4   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/6
# 5         5           0.2432         0.6094    0.9296         0.635           0.938        0.7573   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=3; train_loader.num_augmentations=4; train_loader.batch_size=20  /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/5
# 16        5           0.1922         0.609     0.9283         0.627           0.9549       0.757    trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=4; train_loader.num_augmentations=5; train_loader.batch_size=8   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/16
# 13        4           0.2636         0.6049    0.9285         0.6315          0.935        0.7538   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=4; train_loader.num_augmentations=4; train_loader.batch_size=8   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/13
# 23        5           0.112          0.5979    0.9501         0.9129          0.6341       0.7484   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=pixels; model.num_classes=3; train_loader.num_augmentations=4; train_loader.batch_size=20   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/23
# 9         5           0.2938         0.5953    0.9277         0.6334          0.9081       0.7463   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=4; train_loader.num_augmentations=2; train_loader.batch_size=4   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/9
# 8         5           0.2464         0.5938    0.9255         0.6211          0.9311       0.7452   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=3; train_loader.num_augmentations=5; train_loader.batch_size=20  /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/8
# 21        4           0.0459         0.5777    0.9496         0.966           0.5897       0.7324   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=pixels; model.num_classes=3; train_loader.num_augmentations=4; train_loader.batch_size=4    /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/21
# 0         5           0.2746         0.5614    0.9207         0.614           0.8676       0.7191   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=3; train_loader.num_augmentations=2; train_loader.batch_size=4   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/0
# 10        5           0.3248         0.5539    0.9126         0.5809          0.9225       0.7129   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=4; train_loader.num_augmentations=2; train_loader.batch_size=8   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/10
# 11        5           0.6281         0.5272    0.9068         0.5789          0.8553       0.6905   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=4; train_loader.num_augmentations=2; train_loader.batch_size=20  /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/11
# 1         5           0.2958         0.5144    0.8976         0.5361          0.927        0.6793   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=3; train_loader.num_augmentations=2; train_loader.batch_size=8   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/1
# 22        5           0.0542         0.5071    0.9416         0.9765          0.5134       0.673    trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=pixels; model.num_classes=3; train_loader.num_augmentations=4; train_loader.batch_size=8    /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/22
# 20        5           0.26           0.4829    0.9152         0.6279          0.6765       0.6513   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=pixels; model.num_classes=3; train_loader.num_augmentations=2; train_loader.batch_size=20   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/20
# 2         4           0.5044         0.4809    0.8848         0.5043          0.9122       0.6495   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=inverse; model.num_classes=3; train_loader.num_augmentations=2; train_loader.batch_size=20  /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/2
# 19        5           0.1082         0.3184    0.9196         0.9739          0.3212       0.483    trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=pixels; model.num_classes=3; train_loader.num_augmentations=2; train_loader.batch_size=8    /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/19
# 18        5           0.0708         0.3157    0.9189         0.9605          0.3198       0.4799   trainer.n_epochs=5; model.learning_rate=0.0005; model.apply_weight_loss=True; model.weight_type=pixels; model.num_classes=3; train_loader.num_augmentations=2; train_loader.batch_size=4    /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/18
#
# Best run by best_IoU: 17
# Directory: /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-12_205032/17

# %%
# !python3 ../../scripts/rank_multirun_results.py /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_193723
# Out:
# run_name  best_epoch  best_val_loss  best_IoU  best_Accuracy  best_Precision  best_Recall  best_F1  overrides                                                                                                                                                    run_dir
# --------  ----------  -------------  --------  -------------  --------------  -----------  -------  -----------------------------------------------------------------------------------------------------------------------------------------------------------  -------------------------------------------------------------------------------------------------------------------------------------------------
# 5         3           1.0529         0.1975    0.793          0.4468          0.2615       0.3299   trainer.n_epochs=8; model.learning_rate=0.0005; model.num_classes=3; train_loader.num_augmentations=5; train_loader.batch_size=4; criterion.name=ce          /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_193723/5
# 2         3           1.0235         0.1869    0.8042         0.495           0.2309       0.3149   trainer.n_epochs=5; model.learning_rate=0.0005; model.num_classes=3; train_loader.num_augmentations=5; train_loader.batch_size=4; criterion.name=ce          /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_193723/2
# 4         8           0.4012         0.1604    0.8279         0.7645          0.1688       0.2765   trainer.n_epochs=8; model.learning_rate=0.0005; model.num_classes=3; train_loader.num_augmentations=5; train_loader.batch_size=4; criterion.name=dice        /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_193723/4
# 1         3           0.4408         0.0792    0.8137         0.683           0.0822       0.1468   trainer.n_epochs=5; model.learning_rate=0.0005; model.num_classes=3; train_loader.num_augmentations=5; train_loader.batch_size=4; criterion.name=dice        /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_193723/1
# 3         1           0.4712         0.0663    0.8078         0.5543          0.0701       0.1244   trainer.n_epochs=8; model.learning_rate=0.0005; model.num_classes=3; train_loader.num_augmentations=5; train_loader.batch_size=4; criterion.name=dice_focal  /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_193723/3
# 0         1           0.4799         0.0606    0.8025         0.4541          0.0654       0.1143   trainer.n_epochs=5; model.learning_rate=0.0005; model.num_classes=3; train_loader.num_augmentations=5; train_loader.batch_size=4; criterion.name=dice_focal  /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_193723/0
#
# Best run by best_IoU: 5
# Directory: /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_193723/5

# %%
# !python3 ../../scripts/rank_multirun_results.py /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_200434
# Out:
# run_name  best_epoch  best_val_loss  best_IoU  best_Accuracy  best_Precision  best_Recall  best_F1  overrides                                       run_dir
# --------  ----------  -------------  --------  -------------  --------------  -----------  -------  ----------------------------------------------  -------------------------------------------------------------------------------------------------------------------------------------------------
# 2         3           1.0231         0.2015    0.7922         0.4454          0.269        0.3354   trainer.n_epochs=8; criterion.name=ce           /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_200434/2
# 5         3           1.0886         0.183     0.8114         0.5405          0.2167       0.3094   trainer.n_epochs=20; criterion.name=ce          /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_200434/5
# 1         8           0.4229         0.1624    0.827          0.7432          0.1721       0.2794   trainer.n_epochs=8; criterion.name=dice         /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_200434/1
# 4         3           0.4556         0.0861    0.8181         0.8041          0.088        0.1586   trainer.n_epochs=20; criterion.name=dice        /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_200434/4
# 3         1           0.4625         0.0662    0.8085         0.5726          0.0697       0.1242   trainer.n_epochs=20; criterion.name=dice_focal  /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_200434/3
# 0         1           0.4717         0.063     0.8081         0.565           0.0663       0.1186   trainer.n_epochs=8; criterion.name=dice_focal   /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_200434/0
#
# Best run by best_IoU: 2
# Directory: /users/PGS0218/julina/projects/geography/damage_mapping_terramind/V2/data/experiments/dev-sweeps-large/terramind_large_search_2026-03-26_200434/2

# %%
import os
os.environ['WANDB_API_KEY'] = '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'
